# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51770Supreeth/RL_Lab/blob/main/RL_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Enter number of machines: "))

q = {}

for i in range(n):
    name = input("Enter machine name: ")
    r = list(map(int, input("Enter rewards: ").split()))
    q[name] = sum(r) / len(r)

for name in q:
    print("Machine", name)
    print("Q(" + name + ") =", q[name])

best = max(q, key=q.get)
print("Greedy Selected Machine:", best)
# Out:
# Enter number of machines: 3
# Enter machine name: A
# Enter rewards: 3 2 4
# Enter machine name: B
# Enter rewards: 6 7
# Enter machine name: C
# Enter rewards: 5 7 6
# Machine A
# Q(A) = 3.0
# Machine B
# Q(B) = 6.5
# Machine C
# Q(C) = 6.0
# Greedy Selected Machine: B

# %%
machines = {
    "A": [3, 2, 4],
    "B": [6, 7],
    "C": [5, 4, 6]
}

q = {"A": 0, "B": 0, "C": 0}
n = {"A": 0, "B": 0, "C": 0}

for machine in machines:
    for r in machines[machine]:
        n[machine] += 1
        q[machine] = q[machine] + (r - q[machine]) / n[machine]

        print("Machine:", machine, "Reward:", r, "Q =", q[machine])

best = max(q, key=q.get)

print("\nFinal Q values:")
for machine in q:
    print("Q(" + machine + ") =", q[machine])

print("Greedy Selected Machine:", best)
# Out:
# Machine: A Reward: 3 Q = 3.0
# Machine: A Reward: 2 Q = 2.5
# Machine: A Reward: 4 Q = 3.0
# Machine: B Reward: 6 Q = 6.0
# Machine: B Reward: 7 Q = 6.5
# Machine: C Reward: 5 Q = 5.0
# Machine: C Reward: 4 Q = 4.5
# Machine: C Reward: 6 Q = 5.0
#
# Final Q values:
# Q(A) = 3.0
# Q(B) = 6.5
# Q(C) = 5.0
# Greedy Selected Machine: B
